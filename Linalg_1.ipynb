# %%
# Task 1

import numpy as np
from numpy.linalg import norm


# 1

# fx_4 = fx_3 - fx_2 - fx_1   >>>> векторы линейны


# 2

# fx_4 = fx_3 + 2 * fx_2 + 0.5 * fx_1


# 3

# x = b2 + 3*b3 + 0.5*b1


# 4

# fx_1 = (3x^2, -2, 2/x^2)

# fx_2 = (3, -2x/x-1, 2)


# 5

# a - нет, не является, так как два вектора, у одного из которых первая координата равна нулю, а у второго - втарая, 
# при сложении дадут вектор, обе координаты которого не будут равны нулю.

# б - нет, так как появятся ситуации, когда векторы {u1, u2, ..., u3} будут иметь значения, при которых происходит равенство
# a1*u1 + a2*u2 + ... + an*un = 0 только в случае a1 = a2 = ... = an = 0

# %%
# Task 2


# 1

x1 = np.array([0, -3, 6])
y1 = np.array([-4, 7, 9])

np.dot(x1, y1) # 33

x2 = np.array([7, -4, 0, 1])
y2 = np.array([-3, 1, 11, 2])

np.dot(x2, y2) # -23


# 2

a = np.array([4, 2, 4])
b = np.array([12, 3, 4])

norm(a) # 6
norm(b) # 13

phi = np.arccos(np.dot(a, b) / norm(a) / norm(b))

np.rad2deg(phi) # 26 градусов


# 3

# a) Да, будет, если векторы сонаправлены
# б) Евклидово пространство подразумевает под собой наличие векторов и соответствующее им скалярное произведение. 
#    Если у тройного скалярного произведения есть подобающие векторы, например, (3*u, v) то ответ: ДА, является
#    Если же мы берем скалярное произведение обычных векторов (u, v) и говорим, что его тройная величина также соответствуют
#    этим вектрам (u, v), то это уже не Евклидово пространство.


# 4

# a - не подходит, потому что для R3 базис должен составляють три вектора
# б - не подходит, потому что первые два векторы - это один и тот же вектор
# в - не подходит, потому что скалярное произведение первых двух векторов также не равно нулю
# г - подходит
# Out:
# 26.176952171666557
